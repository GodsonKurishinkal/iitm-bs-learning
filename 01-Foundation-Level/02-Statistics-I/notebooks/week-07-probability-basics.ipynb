# %% [markdown]
# # Week 7: Probability Basics
#
# **Course:** Statistics for Data Science I (BSMA1002)
# **Week:** 7 of 12
#
# ## Learning Objectives
# - Sample space and events
# - Probability axioms
# - Addition and multiplication rules
# - Conditional probability
# - Applications in decision making

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## 1. Sample space and events
#
# ### Key Concepts
# Comprehensive explanation of sample space and events
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Sample space and events
# Comprehensive code examples with visualizations

print('Implementation for: Sample space and events')

# %% [markdown]
# ## 2. Probability axioms
#
# ### Key Concepts
# Comprehensive explanation of probability axioms
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Probability axioms
# Comprehensive code examples with visualizations

print('Implementation for: Probability axioms')

# %% [markdown]
# ## 3. Addition and multiplication rules
#
# ### Key Concepts
# Comprehensive explanation of addition and multiplication rules
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Addition and multiplication rules
# Comprehensive code examples with visualizations

print('Implementation for: Addition and multiplication rules')

# %% [markdown]
# ## 4. Conditional probability
#
# ### Key Concepts
# Comprehensive explanation of conditional probability
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Conditional probability
# Comprehensive code examples with visualizations

print('Implementation for: Conditional probability')

# %% [markdown]
# ## 5. Applications in decision making
#
# ### Key Concepts
# Comprehensive explanation of applications in decision making
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Applications in decision making
# Comprehensive code examples with visualizations

print('Implementation for: Applications in decision making')

# %% [markdown]
# ## Practice Problems
#
# ### Problem 1
# Apply concepts from this week
#
# ### Problem 2
# Integrate multiple topics
#
# ### Problem 3
# Real-world application challenge

# %%
print("="*60)
print("SOLUTIONS")
print("="*60)

# Problem solutions with detailed explanations
print("\n📝 Problem 1: Solution")
print("\n📝 Problem 2: Solution")
print("\n📝 Problem 3: Solution")

print("\n" + "="*60)

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Sample space and events
# 2. Probability axioms
# 3. Addition and multiplication rules
#
# ### 🔑 Key Formulas
# Essential formulas and theorems from this week
#
# ### 🎯 Applications
# How these concepts apply to data science and real-world problems
#
# ### 🚀 Next Week
# **Week 8**
#
# ---
# **🎓 End of Week 7**
