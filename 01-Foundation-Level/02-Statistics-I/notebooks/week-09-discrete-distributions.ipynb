# %% [markdown]
# # Week 9: Discrete Distributions
#
# **Course:** Statistics for Data Science I (BSMA1002)
# **Week:** 9 of 12
#
# ## Learning Objectives
# - Bernoulli and Binomial
# - Poisson distribution
# - Geometric distribution
# - Applications in counting problems
# - Real-world examples

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## 1. Bernoulli and Binomial
#
# ### Key Concepts
# Comprehensive explanation of bernoulli and binomial
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Bernoulli and Binomial
# Comprehensive code examples with visualizations

print('Implementation for: Bernoulli and Binomial')

# %% [markdown]
# ## 2. Poisson distribution
#
# ### Key Concepts
# Comprehensive explanation of poisson distribution
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Poisson distribution
# Comprehensive code examples with visualizations

print('Implementation for: Poisson distribution')

# %% [markdown]
# ## 3. Geometric distribution
#
# ### Key Concepts
# Comprehensive explanation of geometric distribution
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Geometric distribution
# Comprehensive code examples with visualizations

print('Implementation for: Geometric distribution')

# %% [markdown]
# ## 4. Applications in counting problems
#
# ### Key Concepts
# Comprehensive explanation of applications in counting problems
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Applications in counting problems
# Comprehensive code examples with visualizations

print('Implementation for: Applications in counting problems')

# %% [markdown]
# ## 5. Real-world examples
#
# ### Key Concepts
# Comprehensive explanation of real-world examples
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Real-world examples
# Comprehensive code examples with visualizations

print('Implementation for: Real-world examples')

# %% [markdown]
# ## Practice Problems
#
# ### Problem 1
# Apply concepts from this week
#
# ### Problem 2
# Integrate multiple topics
#
# ### Problem 3
# Real-world application challenge

# %%
print("="*60)
print("SOLUTIONS")
print("="*60)

# Problem solutions with detailed explanations
print("\n📝 Problem 1: Solution")
print("\n📝 Problem 2: Solution")
print("\n📝 Problem 3: Solution")

print("\n" + "="*60)

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Bernoulli and Binomial
# 2. Poisson distribution
# 3. Geometric distribution
#
# ### 🔑 Key Formulas
# Essential formulas and theorems from this week
#
# ### 🎯 Applications
# How these concepts apply to data science and real-world problems
#
# ### 🚀 Next Week
# **Week 10**
#
# ---
# **🎓 End of Week 9**
