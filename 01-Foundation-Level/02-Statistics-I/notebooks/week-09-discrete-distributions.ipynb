# %% [markdown]
# # Week 9: Discrete Distributions**Course**: BSMA1002 - Statistics for Data Science I  **Topic**: Binomial and Poisson Distributions## Learning Objectives- Master binomial distribution- Apply Poisson distribution  - Use SciPy for calculations- Solve real-world problems

# %%
import numpy as npimport pandas as pdimport matplotlib.pyplot as pltfrom scipy import statsnp.random.seed(42)plt.style.use('seaborn-v0_8-darkgrid')print("✓ Ready")

# %% [markdown]
# ## 1. Binomial Distribution**n trials, probability p**$$P(X = k) = \binom{n}{k} p^k (1-p)^{n-k}$$- E[X] = np- Var(X) = np(1-p)

# %%
from scipy.stats import binomn, p = 10, 0.3x = range(n+1)probs = [binom.pmf(k, n, p) for k in x]print(f"Binomial(n={n}, p={p})")print(f"E[X] = {n*p:.1f}")fig, ax = plt.subplots(figsize=(10, 5))ax.bar(x, probs, edgecolor='black')ax.set_title(f'Binomial PMF: n={n}, p={p}', fontweight='bold')ax.set_xlabel('k')ax.set_ylabel('P(X=k)')plt.show()

# %% [markdown]
# ## 2. Poisson Distribution**Count of events, rate λ**$$P(X = k) = \frac{\lambda^k e^{-\lambda}}{k!}$$- E[X] = λ- Var(X) = λ

# %%
from scipy.stats import poissonlam = 4x = range(15)probs = [poisson.pmf(k, lam) for k in x]print(f"Poisson(λ={lam})")print(f"E[X] = Var(X) = {lam}")fig, ax = plt.subplots(figsize=(10, 5))ax.bar(x, probs, edgecolor='black', color='orange')ax.set_title(f'Poisson PMF: λ={lam}', fontweight='bold')ax.set_xlabel('k')ax.set_ylabel('P(X=k)')plt.show()

# %% [markdown]
# ## Summary| Distribution | Parameters | Mean | Variance ||--------------|------------|------|----------|| **Binomial** | n, p | np | np(1-p) || **Poisson** | λ | λ | λ |**Next**: Continuous distributions
