# %% [markdown]
# # Week 1: Data Types and Scales
#
# **Course:** Statistics for Data Science I (BSMA1002)
# **Week:** 1 of 12
#
# ## Learning Objectives
# - Qualitative vs quantitative data
# - Nominal, ordinal, interval, ratio scales
# - Data collection methods
# - Sampling techniques
# - Applications in data preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## 1. Qualitative vs quantitative data
#
# ### Key Concepts
# Comprehensive explanation of qualitative vs quantitative data
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Qualitative vs quantitative data
# Comprehensive code examples with visualizations

print('Implementation for: Qualitative vs quantitative data')

# %% [markdown]
# ## 2. Nominal, ordinal, interval, ratio scales
#
# ### Key Concepts
# Comprehensive explanation of nominal, ordinal, interval, ratio scales
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Nominal, ordinal, interval, ratio scales
# Comprehensive code examples with visualizations

print('Implementation for: Nominal, ordinal, interval, ratio scales')

# %% [markdown]
# ## 3. Data collection methods
#
# ### Key Concepts
# Comprehensive explanation of data collection methods
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Data collection methods
# Comprehensive code examples with visualizations

print('Implementation for: Data collection methods')

# %% [markdown]
# ## 4. Sampling techniques
#
# ### Key Concepts
# Comprehensive explanation of sampling techniques
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Sampling techniques
# Comprehensive code examples with visualizations

print('Implementation for: Sampling techniques')

# %% [markdown]
# ## 5. Applications in data preprocessing
#
# ### Key Concepts
# Comprehensive explanation of applications in data preprocessing
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Applications in data preprocessing
# Comprehensive code examples with visualizations

print('Implementation for: Applications in data preprocessing')

# %% [markdown]
# ## Practice Problems
#
# ### Problem 1
# Apply concepts from this week
#
# ### Problem 2
# Integrate multiple topics
#
# ### Problem 3
# Real-world application challenge

# %%
print("="*60)
print("SOLUTIONS")
print("="*60)

# Problem solutions with detailed explanations
print("\n📝 Problem 1: Solution")
print("\n📝 Problem 2: Solution")
print("\n📝 Problem 3: Solution")

print("\n" + "="*60)

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Qualitative vs quantitative data
# 2. Nominal, ordinal, interval, ratio scales
# 3. Data collection methods
#
# ### 🔑 Key Formulas
# Essential formulas and theorems from this week
#
# ### 🎯 Applications
# How these concepts apply to data science and real-world problems
#
# ### 🚀 Next Week
# **Week 2**
#
# ---
# **🎓 End of Week 1**
