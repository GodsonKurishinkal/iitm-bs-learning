# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from typing import TYPE_CHECKING

if TYPE_CHECKING:
    from pandas import DataFrame, Series

# Reproducibility
np.random.seed(42)

# Visualization settings
# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

# %% [markdown]
# ## 1. Variable Classification
# ### 1.1 Theory
# The first step in any data analysis is understanding what type of data you have. This determines appropriate visualizations, summary statistics, and modeling approaches.
#
# ### 1.2 Data Type Hierarchy
# ```
# Variables
# ├── Categorical (Qualitative)
# │   ├── Nominal (no order): Color, Category, Region
# │   └── Ordinal (ordered): Rating, Size (S/M/L)
# └── Numerical (Quantitative)
#     ├── Discrete (countable): Units sold, Number of stores
#     └── Continuous (measurable): Price, Weight, Time
# ```

# %%
# 1. Variable Classification - Demonstration
# TODO: Create sample retail dataset with all data types
pass

# %% [markdown]
# ### 1.3 Supply Chain Application
# **Retail Context**:
# - **Nominal**: Product category, Supplier name, Store location
# - **Ordinal**: Customer satisfaction (1-5), Priority level (Low/Medium/High)
# - **Discrete**: Units ordered, Stockouts per month, Number of SKUs
# - **Continuous**: Lead time (days), Order value ($), Fill rate (%)

# %%
# Supply Chain Example: Classifying Variables in Inventory Data
# TODO: Add inventory dataset with type identification
pass

# %% [markdown]
# ## 2. Appropriate Methods by Data Type
# ### 2.1 Summary Statistics
# | Data Type | Central Tendency | Spread | Visualization |
# |-----------|-----------------|--------|---------------|
# | Nominal | Mode | - | Bar chart, Pie chart |
# | Ordinal | Median, Mode | IQR | Bar chart (ordered) |
# | Discrete | Mean, Median | Std, IQR | Histogram, Bar chart |
# | Continuous | Mean, Median | Std, Range | Histogram, Box plot, KDE |

# %%
# 2. Appropriate Summaries - Implementation
# TODO: Add summary statistics by type
pass

# %% [markdown]
# ## Practice Exercises
# 1. **Exercise 1**: Classify each column in a retail sales dataset.
# 2. **Exercise 2**: Identify the correct summary statistic for each variable type.
# 3. **Exercise 3**: Choose appropriate visualizations for a supply chain KPI dashboard.

# %% [markdown]
# ## Summary
# - Variables are either categorical (qualitative) or numerical (quantitative)
# - Categorical: nominal (no order) or ordinal (ordered)
# - Numerical: discrete (countable) or continuous (measurable)
# - Data type determines appropriate analysis methods
#
# ## Next Week Preview
# Week 2 covers **Categorical Data Analysis** - frequencies, proportions, and visualizations.
#
# ---
# *IIT Madras BS Degree in Data Science*
