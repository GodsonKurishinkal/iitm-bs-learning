# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from typing import TYPE_CHECKING

if TYPE_CHECKING:
    from pandas import DataFrame, Series

np.random.seed(42)
# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 1. Frequency Tables
# ### 1.1 Theory
# Frequency tables summarize categorical data by counting occurrences. Relative frequencies show proportions, enabling comparisons across groups.
#
# ### 1.2 Mathematical Definition
# - **Frequency**: $f_i$ = count of category $i$
# - **Relative Frequency**: $p_i = f_i / n$ where $n$ = total
# - **Cumulative Frequency**: $F_i = \sum_{j=1}^i f_j$

# %%
# 1. Frequency Tables - Implementation
# TODO: Add frequency table construction
pass

# %% [markdown]
# ### 1.3 Supply Chain Application
# **Retail Context**: Product category distribution, supplier breakdown, defect types analysis, and regional sales composition.

# %%
# Supply Chain Example: Product Category Distribution
# TODO: Add category frequency analysis
pass

# %% [markdown]
# ## 2. Visualizing Categorical Data
# ### 2.1 Theory
# Bar charts compare magnitudes across categories. Pie charts show parts of a whole (use sparingly - often bar charts are clearer).
#
# ### 2.2 Best Practices
# - Order bars by frequency (not alphabetically) for insight
# - Limit pie charts to 5-7 categories
# - Use horizontal bars when category names are long

# %%
# 2. Categorical Visualizations - Implementation
# TODO: Add bar charts and pie charts
pass

# %% [markdown]
# ### 2.3 Supply Chain Application
# **Retail Context**: Revenue by product category, order distribution by fulfillment center, inventory breakdown by status (available, reserved, backorder).

# %%
# Supply Chain Example: Inventory Status Visualization
# TODO: Add inventory status charts
pass

# %% [markdown]
# ## Practice Exercises
# 1. **Exercise 1**: Create a frequency table of order types (standard, express, same-day).
# 2. **Exercise 2**: Visualize sales by region with an appropriate chart.
# 3. **Exercise 3**: Analyze supplier distribution and identify the Pareto principle (80/20 rule).

# %% [markdown]
# ## Summary
# - Frequency tables count category occurrences
# - Relative frequencies enable proportion comparisons
# - Bar charts compare categories; pie charts show composition
# - Order categories meaningfully (by frequency, importance)
#
# ## Next Week Preview
# Week 3 covers **Numerical Data Analysis** - histograms, measures of center and spread.
#
# ---
# *IIT Madras BS Degree in Data Science*
