# %% [markdown]
# # Week 5: Dispersion and Variability
#
# **Course:** Statistics for Data Science I (BSMA1002)
# **Week:** 5 of 12
#
# ## Learning Objectives
# - Range and interquartile range
# - Variance and standard deviation
# - Coefficient of variation
# - Outlier detection
# - Applications in quality control

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## 1. Range and interquartile range
#
# ### Key Concepts
# Comprehensive explanation of range and interquartile range
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Range and interquartile range
# Comprehensive code examples with visualizations

print('Implementation for: Range and interquartile range')

# %% [markdown]
# ## 2. Variance and standard deviation
#
# ### Key Concepts
# Comprehensive explanation of variance and standard deviation
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Variance and standard deviation
# Comprehensive code examples with visualizations

print('Implementation for: Variance and standard deviation')

# %% [markdown]
# ## 3. Coefficient of variation
#
# ### Key Concepts
# Comprehensive explanation of coefficient of variation
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Coefficient of variation
# Comprehensive code examples with visualizations

print('Implementation for: Coefficient of variation')

# %% [markdown]
# ## 4. Outlier detection
#
# ### Key Concepts
# Comprehensive explanation of outlier detection
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Outlier detection
# Comprehensive code examples with visualizations

print('Implementation for: Outlier detection')

# %% [markdown]
# ## 5. Applications in quality control
#
# ### Key Concepts
# Comprehensive explanation of applications in quality control
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Applications in quality control
# Comprehensive code examples with visualizations

print('Implementation for: Applications in quality control')

# %% [markdown]
# ## Practice Problems
#
# ### Problem 1
# Apply concepts from this week
#
# ### Problem 2
# Integrate multiple topics
#
# ### Problem 3
# Real-world application challenge

# %%
print("="*60)
print("SOLUTIONS")
print("="*60)

# Problem solutions with detailed explanations
print("\n📝 Problem 1: Solution")
print("\n📝 Problem 2: Solution")
print("\n📝 Problem 3: Solution")

print("\n" + "="*60)

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Range and interquartile range
# 2. Variance and standard deviation
# 3. Coefficient of variation
#
# ### 🔑 Key Formulas
# Essential formulas and theorems from this week
#
# ### 🎯 Applications
# How these concepts apply to data science and real-world problems
#
# ### 🚀 Next Week
# **Week 6**
#
# ---
# **🎓 End of Week 5**
