# %% [markdown]
# # Week 2: Categorical Data Analysis
#
# **Course:** Statistics for Data Science I (BSMA1002)
# **Week:** 2 of 12
#
# ## Learning Objectives
# - Frequency tables and distributions
# - Bar charts and pie charts
# - Contingency tables
# - Chi-square test of independence
# - Applications in EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## 1. Frequency tables and distributions
#
# ### Key Concepts
# Comprehensive explanation of frequency tables and distributions
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Frequency tables and distributions
# Comprehensive code examples with visualizations

print('Implementation for: Frequency tables and distributions')

# %% [markdown]
# ## 2. Bar charts and pie charts
#
# ### Key Concepts
# Comprehensive explanation of bar charts and pie charts
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Bar charts and pie charts
# Comprehensive code examples with visualizations

print('Implementation for: Bar charts and pie charts')

# %% [markdown]
# ## 3. Contingency tables
#
# ### Key Concepts
# Comprehensive explanation of contingency tables
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Contingency tables
# Comprehensive code examples with visualizations

print('Implementation for: Contingency tables')

# %% [markdown]
# ## 4. Chi-square test of independence
#
# ### Key Concepts
# Comprehensive explanation of chi-square test of independence
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Chi-square test of independence
# Comprehensive code examples with visualizations

print('Implementation for: Chi-square test of independence')

# %% [markdown]
# ## 5. Applications in EDA
#
# ### Key Concepts
# Comprehensive explanation of applications in eda
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Applications in EDA
# Comprehensive code examples with visualizations

print('Implementation for: Applications in EDA')

# %% [markdown]
# ## Practice Problems
#
# ### Problem 1
# Apply concepts from this week
#
# ### Problem 2
# Integrate multiple topics
#
# ### Problem 3
# Real-world application challenge

# %%
print("="*60)
print("SOLUTIONS")
print("="*60)

# Problem solutions with detailed explanations
print("\n📝 Problem 1: Solution")
print("\n📝 Problem 2: Solution")
print("\n📝 Problem 3: Solution")

print("\n" + "="*60)

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Frequency tables and distributions
# 2. Bar charts and pie charts
# 3. Contingency tables
#
# ### 🔑 Key Formulas
# Essential formulas and theorems from this week
#
# ### 🎯 Applications
# How these concepts apply to data science and real-world problems
#
# ### 🚀 Next Week
# **Week 3**
#
# ---
# **🎓 End of Week 2**
