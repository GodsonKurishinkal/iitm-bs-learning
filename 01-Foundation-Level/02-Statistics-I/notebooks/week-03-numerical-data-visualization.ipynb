# %% [markdown]
# # Week 3: Numerical Data Visualization
#
# **Course:** Statistics for Data Science I (BSMA1002)
# **Week:** 3 of 12
#
# ## Learning Objectives
# - Histograms and density plots
# - Box plots and violin plots
# - Scatter plots
# - Time series plots
# - Applications in data exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## 1. Histograms and density plots
#
# ### Key Concepts
# Comprehensive explanation of histograms and density plots
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Histograms and density plots
# Comprehensive code examples with visualizations

print('Implementation for: Histograms and density plots')

# %% [markdown]
# ## 2. Box plots and violin plots
#
# ### Key Concepts
# Comprehensive explanation of box plots and violin plots
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Box plots and violin plots
# Comprehensive code examples with visualizations

print('Implementation for: Box plots and violin plots')

# %% [markdown]
# ## 3. Scatter plots
#
# ### Key Concepts
# Comprehensive explanation of scatter plots
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Scatter plots
# Comprehensive code examples with visualizations

print('Implementation for: Scatter plots')

# %% [markdown]
# ## 4. Time series plots
#
# ### Key Concepts
# Comprehensive explanation of time series plots
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Time series plots
# Comprehensive code examples with visualizations

print('Implementation for: Time series plots')

# %% [markdown]
# ## 5. Applications in data exploration
#
# ### Key Concepts
# Comprehensive explanation of applications in data exploration
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Applications in data exploration
# Comprehensive code examples with visualizations

print('Implementation for: Applications in data exploration')

# %% [markdown]
# ## Practice Problems
#
# ### Problem 1
# Apply concepts from this week
#
# ### Problem 2
# Integrate multiple topics
#
# ### Problem 3
# Real-world application challenge

# %%
print("="*60)
print("SOLUTIONS")
print("="*60)

# Problem solutions with detailed explanations
print("\n📝 Problem 1: Solution")
print("\n📝 Problem 2: Solution")
print("\n📝 Problem 3: Solution")

print("\n" + "="*60)

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Histograms and density plots
# 2. Box plots and violin plots
# 3. Scatter plots
#
# ### 🔑 Key Formulas
# Essential formulas and theorems from this week
#
# ### 🎯 Applications
# How these concepts apply to data science and real-world problems
#
# ### 🚀 Next Week
# **Week 4**
#
# ---
# **🎓 End of Week 3**
