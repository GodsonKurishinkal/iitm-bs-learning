# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import factorial, comb, perm
from scipy import stats
from typing import TYPE_CHECKING

if TYPE_CHECKING:
    from pandas import DataFrame, Series

np.random.seed(42)
# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 1. Fundamental Counting Principles
# ### 1.1 Theory
# Counting principles form the foundation of probability. They help calculate the number of possible outcomes.
#
# ### 1.2 Mathematical Definition
# - **Multiplication Principle**: If task A has $m$ ways and task B has $n$ ways, then A AND B can be done in $m \times n$ ways
# - **Addition Principle**: If task A has $m$ ways and task B has $n$ ways (mutually exclusive), then A OR B can be done in $m + n$ ways

# %%
# 1. Counting Principles - Demonstration
# TODO: Add counting examples
pass

# %% [markdown]
# ### 1.3 Supply Chain Application
# **Retail Context**: How many ways to assign 5 products to 3 warehouses? How many unique product configurations exist? These calculations inform capacity planning.

# %%
# Supply Chain Example: Product-Warehouse Assignments
# TODO: Add assignment counting example
pass

# %% [markdown]
# ## 2. Factorials
# ### 2.1 Theory
# Factorials count the number of ways to arrange objects. They grow extremely fast.
#
# ### 2.2 Mathematical Definition
# $$n! = n \times (n-1) \times (n-2) \times \cdots \times 2 \times 1$$
#
# **Special cases**: $0! = 1$, $1! = 1$

# %%
# 2. Factorials - Implementation
# TODO: Add factorial calculations and growth visualization
pass

# %% [markdown]
# ### 2.3 Supply Chain Application
# **Retail Context**: Number of ways to schedule deliveries, arrange products on shelves, or route vehicles. Factorials explain why optimization is needed - exhaustive search becomes impossible.

# %%
# Supply Chain Example: Delivery Scheduling Complexity
# TODO: Add scheduling complexity example
pass

# %% [markdown]
# ## Practice Exercises
# 1. **Exercise 1**: A product has 3 sizes and 4 colors. How many SKUs are needed?
# 2. **Exercise 2**: In how many ways can 6 orders be processed sequentially?
# 3. **Exercise 3**: Why is finding the optimal route for 20 delivery stops computationally hard?

# %% [markdown]
# ## Summary
# - Multiplication principle: AND → multiply
# - Addition principle: OR → add
# - Factorials count arrangements: n! = n × (n-1) × ... × 1
# - Factorial growth explains combinatorial explosion
#
# ## Next Week Preview
# Week 6 covers **Permutations and Combinations** - ordered vs unordered selections.
#
# ---
# *IIT Madras BS Degree in Data Science*
