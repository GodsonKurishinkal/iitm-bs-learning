# %% [markdown]
# #  - WEEK 3
#
# **Course Code**: BSMA1002
# **Date**: 2025-11-15
# **Topics**: Describing numerical data
# Frequency tables for numerical data, Measures of central tendency - Mean, median and mode, Quartiles and percentiles, Measures of dispersion - Range, variance, standard deviation and IQR, Five number summary
#
# **Prerequisites**:
# - Review notes/week-3.md first
# - Ensure Python environment is set up
#
# **Learning Goals**:
# - Implement concepts from lecture notes
# - Practice with code examples
# - Visualize key concepts
# - Solve computational problems

# %%
# Setup: Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set plotting style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

print("✓ Libraries imported successfully")

# %% [markdown]
# ## Example 1: Basic Concepts

# %%
# TODO: Implement basic concept from notes

# %% [markdown]
# ## Visualization

# %%
# TODO: Create visualization

# %% [markdown]
# ## Example 2: Real-World Application

# %%
# TODO: Apply concept to real problem

# %% [markdown]
# ## Practice Problems

# %%
# TODO: Solve practice problems
# Problem 1:

# Problem 2:

# %% [markdown]
# ## Experiments

# %%
# TODO: Experiment with variations

# %% [markdown]
# ## Key Takeaways
#
# **What I learned**:
# -
# -
# -
#
# **Insights from coding**:
# -
# -
#
# **Questions for next session**:
# -
# -
#
# **Next steps**:
# - [ ] Review this week's notes
# - [ ] Complete practice problems
# - [ ] Start next week's material
