# %% [markdown]
# # Week 6: Correlation and Association
#
# **Course:** Statistics for Data Science I (BSMA1002)
# **Week:** 6 of 12
#
# ## Learning Objectives
# - Pearson correlation coefficient
# - Spearman rank correlation
# - Covariance
# - Scatter plots and interpretation
# - Applications in feature selection

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## 1. Pearson correlation coefficient
#
# ### Key Concepts
# Comprehensive explanation of pearson correlation coefficient
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Pearson correlation coefficient
# Comprehensive code examples with visualizations

print('Implementation for: Pearson correlation coefficient')

# %% [markdown]
# ## 2. Spearman rank correlation
#
# ### Key Concepts
# Comprehensive explanation of spearman rank correlation
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Spearman rank correlation
# Comprehensive code examples with visualizations

print('Implementation for: Spearman rank correlation')

# %% [markdown]
# ## 3. Covariance
#
# ### Key Concepts
# Comprehensive explanation of covariance
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Covariance
# Comprehensive code examples with visualizations

print('Implementation for: Covariance')

# %% [markdown]
# ## 4. Scatter plots and interpretation
#
# ### Key Concepts
# Comprehensive explanation of scatter plots and interpretation
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Scatter plots and interpretation
# Comprehensive code examples with visualizations

print('Implementation for: Scatter plots and interpretation')

# %% [markdown]
# ## 5. Applications in feature selection
#
# ### Key Concepts
# Comprehensive explanation of applications in feature selection
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Applications in feature selection
# Comprehensive code examples with visualizations

print('Implementation for: Applications in feature selection')

# %% [markdown]
# ## Practice Problems
#
# ### Problem 1
# Apply concepts from this week
#
# ### Problem 2
# Integrate multiple topics
#
# ### Problem 3
# Real-world application challenge

# %%
print("="*60)
print("SOLUTIONS")
print("="*60)

# Problem solutions with detailed explanations
print("\n📝 Problem 1: Solution")
print("\n📝 Problem 2: Solution")
print("\n📝 Problem 3: Solution")

print("\n" + "="*60)

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Pearson correlation coefficient
# 2. Spearman rank correlation
# 3. Covariance
#
# ### 🔑 Key Formulas
# Essential formulas and theorems from this week
#
# ### 🎯 Applications
# How these concepts apply to data science and real-world problems
#
# ### 🚀 Next Week
# **Week 7**
#
# ---
# **🎓 End of Week 6**
