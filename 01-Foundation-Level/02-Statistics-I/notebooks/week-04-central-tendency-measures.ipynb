# %% [markdown]
# # Week 4: Central Tendency Measures
#
# **Course:** Statistics for Data Science I (BSMA1002)
# **Week:** 4 of 12
#
# ## Learning Objectives
# - Mean, median, mode
# - Weighted mean
# - Trimmed mean
# - When to use each measure
# - Applications in data summaries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## 1. Mean, median, mode
#
# ### Key Concepts
# Comprehensive explanation of mean, median, mode
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Mean, median, mode
# Comprehensive code examples with visualizations

print('Implementation for: Mean, median, mode')

# %% [markdown]
# ## 2. Weighted mean
#
# ### Key Concepts
# Comprehensive explanation of weighted mean
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Weighted mean
# Comprehensive code examples with visualizations

print('Implementation for: Weighted mean')

# %% [markdown]
# ## 3. Trimmed mean
#
# ### Key Concepts
# Comprehensive explanation of trimmed mean
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Trimmed mean
# Comprehensive code examples with visualizations

print('Implementation for: Trimmed mean')

# %% [markdown]
# ## 4. When to use each measure
#
# ### Key Concepts
# Comprehensive explanation of when to use each measure
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: When to use each measure
# Comprehensive code examples with visualizations

print('Implementation for: When to use each measure')

# %% [markdown]
# ## 5. Applications in data summaries
#
# ### Key Concepts
# Comprehensive explanation of applications in data summaries
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Applications in data summaries
# Comprehensive code examples with visualizations

print('Implementation for: Applications in data summaries')

# %% [markdown]
# ## Practice Problems
#
# ### Problem 1
# Apply concepts from this week
#
# ### Problem 2
# Integrate multiple topics
#
# ### Problem 3
# Real-world application challenge

# %%
print("="*60)
print("SOLUTIONS")
print("="*60)

# Problem solutions with detailed explanations
print("\n📝 Problem 1: Solution")
print("\n📝 Problem 2: Solution")
print("\n📝 Problem 3: Solution")

print("\n" + "="*60)

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Mean, median, mode
# 2. Weighted mean
# 3. Trimmed mean
#
# ### 🔑 Key Formulas
# Essential formulas and theorems from this week
#
# ### 🎯 Applications
# How these concepts apply to data science and real-world problems
#
# ### 🚀 Next Week
# **Week 5**
#
# ---
# **🎓 End of Week 4**
