# %% [markdown]
# # Week 9: Limits and Continuity
#
# **Course:** Mathematics for Data Science I (BSMA1001)
# **Week:** 9 of 12
#
# ## Learning Objectives
# - Limit definition and properties
# - One-sided limits
# - Continuity at a point
# - Types of discontinuities
# - Applications in analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import optimize, integrate
import sympy as sp

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
sp.init_printing()
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## 1. Limit definition and properties
#
# ### Key Concepts
# Comprehensive explanation of limit definition and properties
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Limit definition and properties
# Comprehensive code examples with visualizations

print('Implementation for: Limit definition and properties')

# %% [markdown]
# ## 2. One-sided limits
#
# ### Key Concepts
# Comprehensive explanation of one-sided limits
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: One-sided limits
# Comprehensive code examples with visualizations

print('Implementation for: One-sided limits')

# %% [markdown]
# ## 3. Continuity at a point
#
# ### Key Concepts
# Comprehensive explanation of continuity at a point
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Continuity at a point
# Comprehensive code examples with visualizations

print('Implementation for: Continuity at a point')

# %% [markdown]
# ## 4. Types of discontinuities
#
# ### Key Concepts
# Comprehensive explanation of types of discontinuities
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Types of discontinuities
# Comprehensive code examples with visualizations

print('Implementation for: Types of discontinuities')

# %% [markdown]
# ## 5. Applications in analysis
#
# ### Key Concepts
# Comprehensive explanation of applications in analysis
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Applications in analysis
# Comprehensive code examples with visualizations

print('Implementation for: Applications in analysis')

# %% [markdown]
# ## Practice Problems
#
# ### Problem 1
# Apply concepts from this week
#
# ### Problem 2
# Integrate multiple topics
#
# ### Problem 3
# Real-world application challenge

# %%
print("="*60)
print("SOLUTIONS")
print("="*60)

# Problem solutions with detailed explanations
print("\n📝 Problem 1: Solution")
print("\n📝 Problem 2: Solution")
print("\n📝 Problem 3: Solution")

print("\n" + "="*60)

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Limit definition and properties
# 2. One-sided limits
# 3. Continuity at a point
#
# ### 🔑 Key Formulas
# Essential formulas and theorems from this week
#
# ### 🎯 Applications
# How these concepts apply to data science and real-world problems
#
# ### 🚀 Next Week
# **Week 10**
#
# ---
# **🎓 End of Week 9**
