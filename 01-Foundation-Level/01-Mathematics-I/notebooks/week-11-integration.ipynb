# %% [markdown]
# # Week 11: Integration
#
# **Course:** Mathematics for Data Science I (BSMA1001)
# **Week:** 11 of 12
#
# ## Learning Objectives
# - Antiderivatives and indefinite integrals
# - Definite integrals
# - Fundamental theorem of calculus
# - Integration techniques
# - Applications: area under curves

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import optimize, integrate
import sympy as sp

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
sp.init_printing()
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## 1. Antiderivatives and indefinite integrals
#
# ### Key Concepts
# Comprehensive explanation of antiderivatives and indefinite integrals
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Antiderivatives and indefinite integrals
# Comprehensive code examples with visualizations

print('Implementation for: Antiderivatives and indefinite integrals')

# %% [markdown]
# ## 2. Definite integrals
#
# ### Key Concepts
# Comprehensive explanation of definite integrals
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Definite integrals
# Comprehensive code examples with visualizations

print('Implementation for: Definite integrals')

# %% [markdown]
# ## 3. Fundamental theorem of calculus
#
# ### Key Concepts
# Comprehensive explanation of fundamental theorem of calculus
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Fundamental theorem of calculus
# Comprehensive code examples with visualizations

print('Implementation for: Fundamental theorem of calculus')

# %% [markdown]
# ## 4. Integration techniques
#
# ### Key Concepts
# Comprehensive explanation of integration techniques
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Integration techniques
# Comprehensive code examples with visualizations

print('Implementation for: Integration techniques')

# %% [markdown]
# ## 5. Applications: area under curves
#
# ### Key Concepts
# Comprehensive explanation of applications: area under curves
#
# ### Theory
# Mathematical foundations and definitions
#
# ### Applications
# Real-world applications in data science

# %%
# Implementation: Applications: area under curves
# Comprehensive code examples with visualizations

print('Implementation for: Applications: area under curves')

# %% [markdown]
# ## Practice Problems
#
# ### Problem 1
# Apply concepts from this week
#
# ### Problem 2
# Integrate multiple topics
#
# ### Problem 3
# Real-world application challenge

# %%
print("="*60)
print("SOLUTIONS")
print("="*60)

# Problem solutions with detailed explanations
print("\n📝 Problem 1: Solution")
print("\n📝 Problem 2: Solution")
print("\n📝 Problem 3: Solution")

print("\n" + "="*60)

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Antiderivatives and indefinite integrals
# 2. Definite integrals
# 3. Fundamental theorem of calculus
#
# ### 🔑 Key Formulas
# Essential formulas and theorems from this week
#
# ### 🎯 Applications
# How these concepts apply to data science and real-world problems
#
# ### 🚀 Next Week
# **Week 12**
#
# ---
# **🎓 End of Week 11**
