# %% [markdown]
# # Week 5: Vector Spaces
#
# **Course:** Mathematics for Data Science II (BSMA1003)
# **Week:** 5 of 12
#
# ## Learning Objectives
# - Vector space axioms
# - Subspaces
# - Linear combinations
# - Span of vectors
# - Applications in ML feature spaces

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import linalg
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
np.set_printoptions(precision=3, suppress=True)
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## Content for Week 5: Vector Spaces
# Comprehensive content with examples and visualizations

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Vector space axioms
# 2. Subspaces
# 3. Linear combinations
#
# ### 🔑 Key Formulas
# Review the mathematical formulas and theorems covered in this week
#
# ### 🎯 Applications
# Real-world applications in data science and machine learning
#
# ### 🚀 Next Week
# **Week 6**
#
# ---
# **🎓 End of Week 5**
