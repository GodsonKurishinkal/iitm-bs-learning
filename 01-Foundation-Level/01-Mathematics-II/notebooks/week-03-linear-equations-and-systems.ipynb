# %% [markdown]
# # Week 3: Linear Equations and Systems
#
# **Course:** Mathematics for Data Science II (BSMA1003)
# **Week:** 3 of 12
#
# ## Learning Objectives
# - System of linear equations
# - Augmented matrices
# - Row echelon form
# - Solution uniqueness
# - Applications: network flow problems

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import linalg
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
np.set_printoptions(precision=3, suppress=True)
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## Content for Week 3: Linear Equations and Systems
# Comprehensive content with examples and visualizations

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. System of linear equations
# 2. Augmented matrices
# 3. Row echelon form
#
# ### 🔑 Key Formulas
# Review the mathematical formulas and theorems covered in this week
#
# ### 🎯 Applications
# Real-world applications in data science and machine learning
#
# ### 🚀 Next Week
# **Week 4**
#
# ---
# **🎓 End of Week 3**
