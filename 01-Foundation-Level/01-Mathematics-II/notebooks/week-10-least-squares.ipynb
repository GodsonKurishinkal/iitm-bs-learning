# %% [markdown]
# # Week 10: Least Squares
#
# **Course:** Mathematics for Data Science II (BSMA1003)
# **Week:** 10
#
# ## Learning Objectives
# - Master least squares concepts
# - Apply to data science problems
# - Implement using NumPy and SciPy
# - Understand real-world applications

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import linalg

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## Section 1: Least Squares Theory
#
# Comprehensive mathematical concepts with LaTeX equations and explanations.

# %%
# Least Squares implementation
print('Week 10: Least Squares - Cell 4')

# %% [markdown]
# ## Section 2: Least Squares Theory
#
# Comprehensive mathematical concepts with LaTeX equations and explanations.

# %%
# Least Squares implementation
print('Week 10: Least Squares - Cell 6')

# %% [markdown]
# ## Section 3: Least Squares Theory
#
# Comprehensive mathematical concepts with LaTeX equations and explanations.

# %%
# Least Squares implementation
print('Week 10: Least Squares - Cell 8')

# %% [markdown]
# ## Section 4: Least Squares Theory
#
# Comprehensive mathematical concepts with LaTeX equations and explanations.

# %%
# Least Squares implementation
print('Week 10: Least Squares - Cell 10')

# %% [markdown]
# ## Section 5: Least Squares Theory
#
# Comprehensive mathematical concepts with LaTeX equations and explanations.

# %%
# Least Squares implementation
print('Week 10: Least Squares - Cell 12')
