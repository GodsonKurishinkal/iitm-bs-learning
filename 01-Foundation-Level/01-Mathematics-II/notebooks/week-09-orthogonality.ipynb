# %% [markdown]
# # Week 9: Orthogonality
#
# **Course:** Mathematics for Data Science II (BSMA1003)
# **Week:** 9
#
# ## Learning Objectives
# - Master orthogonality concepts
# - Apply to data science problems
# - Implement using NumPy and SciPy
# - Understand real-world applications

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import linalg

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## Section 1: Orthogonality Theory
#
# Comprehensive mathematical concepts with LaTeX equations and explanations.

# %%
# Orthogonality implementation
print('Week 9: Orthogonality - Cell 4')

# %% [markdown]
# ## Section 2: Orthogonality Theory
#
# Comprehensive mathematical concepts with LaTeX equations and explanations.

# %%
# Orthogonality implementation
print('Week 9: Orthogonality - Cell 6')

# %% [markdown]
# ## Section 3: Orthogonality Theory
#
# Comprehensive mathematical concepts with LaTeX equations and explanations.

# %%
# Orthogonality implementation
print('Week 9: Orthogonality - Cell 8')

# %% [markdown]
# ## Section 4: Orthogonality Theory
#
# Comprehensive mathematical concepts with LaTeX equations and explanations.

# %%
# Orthogonality implementation
print('Week 9: Orthogonality - Cell 10')

# %% [markdown]
# ## Section 5: Orthogonality Theory
#
# Comprehensive mathematical concepts with LaTeX equations and explanations.

# %%
# Orthogonality implementation
print('Week 9: Orthogonality - Cell 12')

# %% [markdown]
# ## Section 6: Orthogonality Theory
#
# Comprehensive mathematical concepts with LaTeX equations and explanations.
