# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline

# %% [markdown]
# ## 1. Exponential Functions
#
# ### Definition
# $$f(x) = a^x$$ where $a > 0, a \neq 1$
#
# ### Properties
# - Domain: $(-\infty, \infty)$
# - Range: $(0, \infty)$
# - Always positive
# - If $a > 1$: exponential growth
# - If $0 < a < 1$: exponential decay
#
# ### Laws of Exponents
# - $a^m \cdot a^n = a^{m+n}$
# - $\frac{a^m}{a^n} = a^{m-n}$
# - $(a^m)^n = a^{mn}$
# - $a^0 = 1$
# - $a^{-n} = \frac{1}{a^n}$

# %%
# Visualize exponential functions
x = np.linspace(-3, 3, 300)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Exponential growth
bases_growth = [2, 3, 10]
for base in bases_growth:
    y = base**x
    ax1.plot(x, y, linewidth=2, label=f'f(x) = {base}^x')

ax1.axhline(y=0, color='k', linewidth=0.5)
ax1.axvline(x=0, color='k', linewidth=0.5)
ax1.axhline(y=1, color='gray', linewidth=0.5, linestyle='--', alpha=0.5)
ax1.grid(True, alpha=0.3)
ax1.set_xlabel('x')
ax1.set_ylabel('f(x)')
ax1.set_title('Exponential Growth (a > 1)')
ax1.set_ylim(0, 10)
ax1.legend()

# Exponential decay
bases_decay = [0.5, 0.25, 0.1]
for base in bases_decay:
    y = base**x
    ax2.plot(x, y, linewidth=2, label=f'f(x) = {base}^x')

ax2.axhline(y=0, color='k', linewidth=0.5)
ax2.axvline(x=0, color='k', linewidth=0.5)
ax2.axhline(y=1, color='gray', linewidth=0.5, linestyle='--', alpha=0.5)
ax2.grid(True, alpha=0.3)
ax2.set_xlabel('x')
ax2.set_ylabel('f(x)')
ax2.set_title('Exponential Decay (0 < a < 1)')
ax2.set_ylim(0, 10)
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. The Natural Exponential Function
#
# ### Euler's Number
# $$e = \lim_{n \to \infty} \left(1 + \frac{1}{n}\right)^n \approx 2.71828...$$
#
# ### Natural Exponential Function
# $$f(x) = e^x$$
#
# ### Applications
# - Continuous compound interest
# - Population growth
# - Radioactive decay
# - Natural processes

# %%
# Demonstrate convergence to e
n_values = [1, 10, 100, 1000, 10000, 100000]
print("Convergence to e:")
print("="*50)
for n in n_values:
    approx_e = (1 + 1/n)**n
    error = abs(np.e - approx_e)
    print(f"n = {n:7d}: (1 + 1/n)^n = {approx_e:.10f}, error = {error:.2e}")

print(f"\nActual e = {np.e:.15f}")

# Compare exponential functions
x = np.linspace(-2, 3, 300)

plt.figure(figsize=(10, 6))
plt.plot(x, 2**x, 'b-', linewidth=2, label='f(x) = 2^x')
plt.plot(x, np.e**x, 'r-', linewidth=2, label='f(x) = e^x')
plt.plot(x, 3**x, 'g-', linewidth=2, label='f(x) = 3^x')
plt.axhline(y=0, color='k', linewidth=0.5)
plt.axvline(x=0, color='k', linewidth=0.5)
plt.grid(True, alpha=0.3)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Comparison of Exponential Functions')
plt.ylim(0, 20)
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Inverse Functions
#
# ### Definition
# Function $g$ is the **inverse** of function $f$ if:
# $$f(g(x)) = x \text{ and } g(f(x)) = x$$
#
# Notation: $g = f^{-1}$ (not to be confused with $\frac{1}{f}$)
#
# ### Properties
# - Only **one-to-one** functions have inverses
# - Domain of $f$ = Range of $f^{-1}$
# - Range of $f$ = Domain of $f^{-1}$
# - Graph of $f^{-1}$ is reflection of $f$ across $y = x$
#
# ### Horizontal Line Test
# A function has an inverse if any horizontal line intersects its graph at most once.

# %%
def find_inverse_symbolically(func_expr, x_sym, y_sym):
    """Find inverse function symbolically"""
    # Solve y = f(x) for x in terms of y
    inverse_expr = sp.solve(y_sym - func_expr, x_sym)
    return inverse_expr

# Example: f(x) = 2x + 3
x, y = sp.symbols('x y')
f = 2*x + 3

print("Finding Inverse Function")
print("="*50)
print(f"f(x) = {f}")
print("\nStep 1: Replace f(x) with y")
print(f"y = {f}")
print("\nStep 2: Solve for x in terms of y")

inverse = find_inverse_symbolically(f, x, y)
print(f"x = {inverse[0]}")
print("\nStep 3: Swap x and y")
f_inv = inverse[0].subs(y, x)
print(f"f⁻¹(x) = {f_inv}")

# Verify
print("\nVerification:")
f_of_inv = f.subs(x, f_inv)
print(f"f(f⁻¹(x)) = {sp.simplify(f_of_inv)}")
inv_of_f = f_inv.subs(x, f)
print(f"f⁻¹(f(x)) = {sp.simplify(inv_of_f)}")

# %%
# Visualize function and its inverse
x_vals = np.linspace(-5, 5, 200)
f_vals = 2*x_vals + 3  # f(x) = 2x + 3
f_inv_vals = (x_vals - 3)/2  # f⁻¹(x) = (x-3)/2

plt.figure(figsize=(10, 10))
plt.plot(x_vals, f_vals, 'b-', linewidth=2, label='f(x) = 2x + 3')
plt.plot(x_vals, f_inv_vals, 'r-', linewidth=2, label='f⁻¹(x) = (x-3)/2')
plt.plot(x_vals, x_vals, 'g--', linewidth=1, alpha=0.5, label='y = x (line of reflection)')

# Mark corresponding points
points = [(0, 3), (1, 5), (2, 7)]
for px, py in points:
    plt.plot(px, py, 'bo', markersize=8)
    plt.plot(py, px, 'ro', markersize=8)
    plt.plot([px, py], [py, px], 'gray', linestyle=':', alpha=0.5)

plt.axhline(y=0, color='k', linewidth=0.5)
plt.axvline(x=0, color='k', linewidth=0.5)
plt.grid(True, alpha=0.3)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Function and Its Inverse (reflected across y=x)')
plt.legend()
plt.axis('equal')
plt.xlim(-5, 10)
plt.ylim(-5, 10)
plt.show()

# %% [markdown]
# ## 4. Function Composition
#
# ### Definition
# $$(f \circ g)(x) = f(g(x))$$
#
# Read as "f composed with g"
#
# ### Properties
# - Generally not commutative: $f \circ g \neq g \circ f$
# - Domain of $f \circ g$: values in domain of $g$ where $g(x)$ is in domain of $f$
#
# ### Inverse Composition
# - $f(f^{-1}(x)) = x$
# - $f^{-1}(f(x)) = x$

# %%
# Function composition examples
x = sp.Symbol('x')

f = x**2 + 1
g = 2*x - 3

print("Function Composition")
print("="*60)
print(f"f(x) = {f}")
print(f"g(x) = {g}")
print()

# f(g(x))
f_of_g = f.subs(x, g)
f_of_g_expanded = sp.expand(f_of_g)
print(f"(f ∘ g)(x) = f(g(x)) = {f_of_g}")
print(f"           = {f_of_g_expanded}")
print()

# g(f(x))
g_of_f = g.subs(x, f)
g_of_f_expanded = sp.expand(g_of_f)
print(f"(g ∘ f)(x) = g(f(x)) = {g_of_f}")
print(f"           = {g_of_f_expanded}")
print()

print("Note: f ∘ g ≠ g ∘ f (not commutative)")

# Evaluate at specific value
x_val = 2
print(f"\nAt x = {x_val}:")
print(f"f(g({x_val})) = {f_of_g_expanded.subs(x, x_val)}")
print(f"g(f({x_val})) = {g_of_f_expanded.subs(x, x_val)}")

# %% [markdown]
# ## 5. Applications

# %%
# Application: Compound Interest
print("Compound Interest Formula")
print("="*60)
print("A = P(1 + r/n)^(nt)")
print("where:")
print("  A = final amount")
print("  P = principal (initial amount)")
print("  r = annual interest rate (decimal)")
print("  n = number of times compounded per year")
print("  t = time in years")
print()

# Example
P = 1000  # $1000
r = 0.05  # 5% annual rate
t = np.linspace(0, 20, 100)

# Different compounding frequencies
n_values = {'Annually': 1, 'Quarterly': 4, 'Monthly': 12, 'Daily': 365, 'Continuously': np.inf}

plt.figure(figsize=(12, 6))
for label, n in n_values.items():
    if n == np.inf:
        # Continuous compounding: A = Pe^(rt)
        A = P * np.exp(r * t)
    else:
        A = P * (1 + r/n)**(n*t)
    plt.plot(t, A, linewidth=2, label=label)

plt.axhline(y=P, color='gray', linestyle='--', alpha=0.5, label='Principal')
plt.grid(True, alpha=0.3)
plt.xlabel('Time (years)')
plt.ylabel('Amount ($)')
plt.title(f'Compound Interest: ${P} at {r*100}% annual rate')
plt.legend()
plt.show()

print(f"\nStarting with ${P} at {r*100}% annual rate:")
for label, n in n_values.items():
    if n == np.inf:
        A_20 = P * np.exp(r * 20)
    else:
        A_20 = P * (1 + r/n)**(n*20)
    print(f"{label:15s}: ${A_20:,.2f} after 20 years")

# %% [markdown]
# ## 6. Practice Problems

# %%
# Problem 1: Find inverse
x, y = sp.symbols('x y')
print("Problem 1: Find the inverse of f(x) = (x + 2)/3")
print("="*60)

f1 = (x + 2)/3
inv1 = find_inverse_symbolically(f1, x, y)
f1_inv = inv1[0].subs(y, x)

print(f"f(x) = {f1}")
print(f"f⁻¹(x) = {f1_inv}")
print(f"Simplified: f⁻¹(x) = {sp.simplify(f1_inv)}")

# Problem 2: Composition
print("\n\nProblem 2: If f(x) = x² and g(x) = x + 1, find (f ∘ g)(x)")
print("="*60)

f2 = x**2
g2 = x + 1
fog = f2.subs(x, g2)

print(f"f(x) = {f2}")
print(f"g(x) = {g2}")
print(f"(f ∘ g)(x) = f(g(x)) = f({g2})")
print(f"           = ({g2})²")
print(f"           = {sp.expand(fog)}")

# Problem 3: Exponential growth
print("\n\nProblem 3: Population doubles every 10 years")
print("="*60)
print("Initial population: 1000")
print("Find population after 30 years")
print()
P0 = 1000
doubling_time = 10
t_target = 30
P_t = P0 * 2**(t_target/doubling_time)
print(f"P(t) = {P0} × 2^(t/10)")
print(f"P(30) = {P0} × 2^(30/10)")
print(f"      = {P0} × 2^3")
print(f"      = {P0} × 8")
print(f"      = {P_t:.0f}")

# %% [markdown]
# ## Summary
#
# ### Key Concepts
# 1. **Exponential Functions**: $f(x) = a^x$ where $a > 0, a \neq 1$
# 2. **Natural Exponential**: $f(x) = e^x$ where $e \approx 2.71828$
# 3. **Inverse Functions**: $f^{-1}$ satisfies $f(f^{-1}(x)) = x$
# 4. **Composition**: $(f \circ g)(x) = f(g(x))$
#
# ### Important Properties
# - Exponential functions are always positive
# - Only one-to-one functions have inverses
# - Graph of inverse is reflection across $y = x$
# - Function composition is not commutative
#
# ### Applications
# - Compound interest
# - Population growth
# - Radioactive decay
# - Natural processes
#
# ### Next Week
# Week 06: Logarithmic Functions

# %% [markdown]
# # 📊 Week 5 Comprehensive Summary
#
# ---
#
# ## 🎯 Concepts Mastered
#
# | # | Concept | Key Skills | Confidence (1-5) |
# |---|---------|-----------|------------------|
# | 1 | **Exponential Functions** | Graph, evaluate, apply laws of exponents | ___/5 |
# | 2 | **Growth vs Decay** | Distinguish a>1 from 0<a<1, predict behavior | ___/5 |
# | 3 | **Natural Exponential e** | Understand e's definition, continuous compounding | ___/5 |
# | 4 | **One-to-One Functions** | Apply horizontal line test, verify injectivity | ___/5 |
# | 5 | **Inverse Functions** | Find inverse algebraically, verify composition | ___/5 |
# | 6 | **Reflection Property** | Graph f and f⁻¹ across y=x | ___/5 |
# | 7 | **Function Composition** | Compute (f∘g)(x), understand order matters | ___/5 |
# | 8 | **Compound Interest** | Apply exponential models to finance | ___/5 |
# | 9 | **Exponential Applications** | Model growth/decay in real contexts | ___/5 |
#
# **Average Confidence:** ___/5
# **Target:** 4+/5 for all topics
#
# ---
#
# ## 💡 Core Insights
#
# ### 1. **Exponentials Dominate Polynomials** 🚀
#    - **Fact:** For any polynomial P(x) and exponential aˣ (a>1), eventually aˣ > P(x)
#    - **Example:** 2ˣ overtakes x¹⁰⁰⁰ around x ≈ 10,000
#    - **Why:** Polynomials grow like power law, exponentials grow multiplicatively
#    - **DS Connection:** Why neural networks use exponential activations (sigmoid, softmax)
#    - **Consequence:** Computational complexity class hierarchy (P vs NP vs EXP)
#
# ### 2. **e is the Natural Base** 🌿
#    - **Definition:** e = lim(n→∞) (1 + 1/n)ⁿ ≈ 2.71828...
#    - **Why natural?** eˣ is its own derivative: d/dx(eˣ) = eˣ
#    - **Applications:**
#      - Continuous compounding: A = Pe^(rt)
#      - Normal distribution: exp(-x²/2)
#      - Softmax: exp(xᵢ)/Σexp(xⱼ)
#      - Exponential family distributions
#    - **ML Connection:** Cross-entropy loss uses natural log (ln)
#
# ### 3. **Inverse Functions Undo Operations** 🔄
#    - **Intuition:** f maps A→B, f⁻¹ maps B→A (reverse direction)
#    - **Requirement:** f must be one-to-one (horizontal line test)
#    - **Geometric:** Reflection across y=x line
#    - **Examples:**
#      - f(x) = 2x + 3 ⟺ f⁻¹(x) = (x-3)/2
#      - f(x) = x³ ⟺ f⁻¹(x) = ∛x
#      - f(x) = eˣ ⟺ f⁻¹(x) = ln(x) (next week!)
#    - **ML Connection:** Normalizing flows use invertible transformations
#
# ### 4. **Function Composition is Function Chaining** 🔗
#    - **(f∘g)(x) = f(g(x))**: Apply g first, then f
#    - **Not commutative:** f∘g ≠ g∘f (order matters!)
#    - **Neural networks:** Each layer is composition: h(x) = σ(Wx + b)
#    - **Deep learning:** Network = f₁∘f₂∘...∘fₙ (composition of transformations)
#    - **Backpropagation:** Chain rule for compositions: d/dx(f∘g) = f'(g)·g'
#
# ### 5. **Exponential Growth is Multiplicative** ×2
#    - **Linear growth:** Add constant (f(x+1) = f(x) + c)
#    - **Exponential growth:** Multiply by constant (f(x+1) = f(x) × r)
#    - **Doubling time:** Time for quantity to double (independent of starting value)
#    - **Examples:**
#      - Population: P(t) = P₀·2^(t/T_double)
#      - Moore's Law: Transistor count doubles every ~2 years
#      - Compound interest: Money grows exponentially
#      - Pandemic spread: Cases grow exponentially (early stages)
#
# ### 6. **Domain and Range Swap for Inverses** ⇄
#    - **f:** Domain A → Range B
#    - **f⁻¹:** Domain B → Range A
#    - **Consequence:**
#      - If f: ℝ → (0,∞), then f⁻¹: (0,∞) → ℝ
#      - Example: eˣ: ℝ → (0,∞), ln(x): (0,∞) → ℝ
#    - **Practical:** Check domain restrictions when finding inverses
#
# ### 7. **Exponentials Model Natural Processes** 🌍
#    - **Continuous processes:** Use eˣ (natural base)
#    - **Discrete processes:** Use aˣ (any base)
#    - **Applications:**
#      - Radioactive decay: N(t) = N₀e^(-λt)
#      - Newton's cooling: T(t) = T_ambient + (T₀ - T_ambient)e^(-kt)
#      - Capacitor discharge: Q(t) = Q₀e^(-t/RC)
#      - Drug concentration: C(t) = C₀e^(-kt)
#    - **ML:** Exponential decay for learning rate scheduling
#
# ### 8. **Horizontal Line Test Determines Invertibility** ↔
#    - **Test:** If any horizontal line intersects graph ≤1 time, function is one-to-one
#    - **Examples:**
#      - f(x) = x²: Fails (not one-to-one on ℝ)
#      - f(x) = x³: Passes (one-to-one)
#      - f(x) = eˣ: Passes (one-to-one)
#    - **Fix non-injective:** Restrict domain (e.g., x² on [0,∞))
#    - **Why matters:** Only one-to-one functions have inverses
#
# ---
#
# ## 📐 Formula Reference Sheet
#
# ### Exponential Functions
# 1. **Definition:** f(x) = aˣ where a > 0, a ≠ 1
# 2. **Domain:** (-∞, ∞) (all real numbers)
# 3. **Range:** (0, ∞) (always positive)
# 4. **Natural base:** e = lim(n→∞)(1 + 1/n)ⁿ ≈ 2.71828
#
# ### Laws of Exponents
# 5. **Product:** aᵐ · aⁿ = aᵐ⁺ⁿ
# 6. **Quotient:** aᵐ / aⁿ = aᵐ⁻ⁿ
# 7. **Power of power:** (aᵐ)ⁿ = aᵐⁿ
# 8. **Zero exponent:** a⁰ = 1
# 9. **Negative exponent:** a⁻ⁿ = 1/aⁿ
# 10. **Fractional exponent:** a^(m/n) = ⁿ√(aᵐ) = (ⁿ√a)ᵐ
#
# ### Inverse Functions
# 11. **Definition:** f(f⁻¹(x)) = x and f⁻¹(f(x)) = x
# 12. **Domain swap:** Domain(f) = Range(f⁻¹)
# 13. **Range swap:** Range(f) = Domain(f⁻¹)
# 14. **Graph property:** (a,b) on f ⟺ (b,a) on f⁻¹ (reflection across y=x)
#
# ### Finding Inverse Algorithm
# 15. **Step 1:** Replace f(x) with y
# 16. **Step 2:** Solve for x in terms of y
# 17. **Step 3:** Swap x and y
# 18. **Step 4:** Replace y with f⁻¹(x)
#
# ### Function Composition
# 19. **(f∘g)(x) = f(g(x))**: Apply g first, then f to result
# 20. **Not commutative:** f∘g ≠ g∘f (generally)
# 21. **Domain:** x ∈ Domain(g) where g(x) ∈ Domain(f)
#
# ### Applications
# 22. **Compound interest:** A = P(1 + r/n)^(nt)
# 23. **Continuous compounding:** A = Pe^(rt)
# 24. **Exponential growth:** P(t) = P₀·a^t = P₀·e^(kt)
# 25. **Exponential decay:** N(t) = N₀·a^(-t) = N₀·e^(-λt)
# 26. **Doubling time:** T_double = ln(2)/k ≈ 0.693/k
#
# ---
#
# ## ✅ Self-Assessment Checklist
#
# **Exponential Functions:**
# - [ ] Can evaluate aˣ for any a>0 and x∈ℝ
# - [ ] Know domain (-∞,∞) and range (0,∞) by heart
# - [ ] Distinguish growth (a>1) from decay (0<a<1) instantly
# - [ ] Apply all laws of exponents correctly
# - [ ] Explain why exponentials are always positive
#
# **Natural Exponential:**
# - [ ] Understand e's definition as limit
# - [ ] Approximate e ≈ 2.718
# - [ ] Explain why e is "natural" (own derivative)
# - [ ] Apply continuous compounding formula
# - [ ] Recognize e in normal distribution, softmax, etc.
#
# **Inverse Functions:**
# - [ ] Apply horizontal line test correctly
# - [ ] Find inverse algebraically (swap and solve)
# - [ ] Verify f(f⁻¹(x)) = x and f⁻¹(f(x)) = x
# - [ ] Graph function and inverse (reflection across y=x)
# - [ ] Know domain/range swap property
#
# **Function Composition:**
# - [ ] Evaluate (f∘g)(x) = f(g(x)) correctly
# - [ ] Remember order matters: f∘g ≠ g∘f
# - [ ] Find domain of composition
# - [ ] Verify inverse composition: f∘f⁻¹ = f⁻¹∘f = identity
# - [ ] Chain multiple compositions
#
# **Applications:**
# - [ ] Model population growth/decay
# - [ ] Calculate compound interest (discrete and continuous)
# - [ ] Determine doubling/halving times
# - [ ] Apply exponentials to real-world problems
# - [ ] Connect to ML concepts (softmax, activations)
#
# **Problem-Solving:**
# - [ ] Choose appropriate base (e for continuous, other for discrete)
# - [ ] Solve exponential equations (preview next week)
# - [ ] Interpret graphs of exponential functions
# - [ ] Verify inverse relationships
# - [ ] Apply function composition strategically
#
# ---
#
# ## 🔗 Data Science Connections
#
# ### 1. **Machine Learning: Activation Functions** 🧠
#    ```python
#    # Sigmoid (logistic function)
#    σ(x) = 1/(1 + e^(-x)) = e^x/(e^x + 1)
#
#    # Softmax (multi-class classification)
#    softmax(x)ᵢ = e^(xᵢ)/Σⱼ e^(xⱼ)
#
#    # Exponential Linear Unit (ELU)
#    ELU(x) = x if x≥0 else α(e^x - 1)
#    ```
#    - **Why exponentials?** Smooth, differentiable, bounded/unbounded mix
#    - **Sigmoid:** Maps ℝ → (0,1), natural for probabilities
#    - **Softmax:** Generalizes sigmoid to K classes
#
# ### 2. **Statistics: Exponential Family Distributions** 📊
#    - **General form:** p(x|θ) = h(x)exp(η(θ)T(x) - A(θ))
#    - **Examples:** Normal, exponential, gamma, Poisson, Bernoulli
#    - **Advantage:** Conjugate priors, sufficient statistics
#    - **ML Connection:** Generalized linear models (GLMs)
#
# ### 3. **Optimization: Learning Rate Schedules** 📉
#    ```python
#    # Exponential decay
#    lr(t) = lr₀ · e^(-λt)
#
#    # Step decay
#    lr(t) = lr₀ · γ^(⌊t/step_size⌋)
#    ```
#    - **Purpose:** Start with large steps, refine with small steps
#    - **Exponential decay:** Smooth, continuous decrease
#    - **Prevents overshooting:** Converges to minimum
#
# ### 4. **Information Theory: Entropy & Cross-Entropy** 🔢
#    ```python
#    # Entropy
#    H(p) = -Σᵢ pᵢ log(pᵢ)
#
#    # Cross-entropy loss
#    L = -Σᵢ yᵢ log(ŷᵢ)
#    ```
#    - **Logarithms:** Inverse of exponentials (next week!)
#    - **Why log?** Converts products to sums (numerical stability)
#    - **ML:** Standard loss for classification
#
# ### 5. **Deep Learning: Normalizing Flows** 🌊
#    - **Idea:** Transform simple distribution (Gaussian) to complex via invertible functions
#    - **Requirement:** Each transformation must be bijective (invertible)
#    - **Change of variables:** p_Y(y) = p_X(f⁻¹(y)) |det(J_f⁻¹(y))|
#    - **Applications:** Generative models, variational inference
#
# ### 6. **Time Series: Growth Models** 📈
#    - **Exponential trend:** y(t) = ae^(bt)
#    - **Logistic growth:** y(t) = L/(1 + e^(-k(t-t₀))) (bounded exponential)
#    - **AR/MA models:** Use exponential weights for past values
#    - **Forecasting:** Exponential smoothing methods
#
# ---
#
# ## 🚀 Week 6 Preview: Logarithmic Functions
#
# ### What's Next?
# - **Logarithms:** Inverse of exponentials
# - **Log properties:** Product, quotient, power rules
# - **Change of base:** Convert between log bases
# - **Applications:** pH scale, Richter scale, decibels
# - **Solving exponential equations:** Use logs!
#
# ### Connection to Week 5
# - **Inverse relationship:** log_a(aˣ) = x and a^(log_a(x)) = x
# - **Natural log:** ln(x) = log_e(x) (inverse of eˣ)
# - **Graph:** Reflection of y = aˣ across y = x
# - **Domain/Range swap:**
#   - eˣ: Domain ℝ, Range (0,∞)
#   - ln(x): Domain (0,∞), Range ℝ
#
# ### Preview Problem
# **Solve for x: 2ˣ = 32**
# <details><summary>Hint</summary>Express 32 as a power of 2, or use logarithms: x = log₂(32)</details>
# <details><summary>Answer</summary>32 = 2⁵, so x = 5. Or using logs: x = log₂(32) = log₂(2⁵) = 5</details>
#
# ---
#
# ## 📚 Additional Resources
#
# ### 📺 Video Lectures
# 1. **Khan Academy - Exponential Functions** (45 min)
#    - Laws of exponents, graphing, applications
#    - [Link](https://www.khanacademy.org/math/algebra2/exponential-and-logarithmic-functions)
#
# 2. **3Blue1Brown - Euler's Formula** (20 min)
#    - Deep dive into e^(iπ) + 1 = 0
#    - Beautiful visualization
#    - [YouTube](https://www.youtube.com/watch?v=mvmuCPvRoWQ)
#
# 3. **MIT OCW - Exponential Growth** (50 min)
#    - Mathematical modeling with exponentials
#    - Real-world applications
#
# ### 📖 Textbook Sections
# - **Stewart Precalculus:** Chapter 4.1-4.2 (Exponential Functions, Inverse Functions)
# - **Larson Algebra:** Chapter 3 (Exponential and Logarithmic Functions)
# - **Strang Calculus:** Chapter 6 (Exponential and Logarithm)
#
# ### 🛠️ Interactive Tools
# - **Desmos - Exponential Exploration:**
#   - Graph y = aˣ with slider for a
#   - Compare different bases
#   - [Link](https://www.desmos.com/calculator)
#
# - **GeoGebra - Inverse Functions:**
#   - Visualize f and f⁻¹ simultaneously
#   - See reflection across y=x dynamically
#   - [Link](https://www.geogebra.org/graphing)
#
# - **Wolfram Alpha:**
#   - "inverse of f(x) = 2x + 3"
#   - "compose x^2 and x+1"
#   - [Link](https://www.wolframalpha.com)
#
# ### 💻 Practice Problems
# - **Paul's Online Math Notes:** Exponential functions practice
# - **IIT Madras Problem Sets:** Week 5 assignments
# - **MIT OCW:** Problem sets with solutions
#
# ---
#
# ## ❓ Thought-Provoking Questions
#
# ### Question 1: Why is eˣ its own derivative?
# **Context:** d/dx(eˣ) = eˣ is unique among exponentials. For aˣ, d/dx(aˣ) = aˣ ln(a).
#
# <details>
# <summary>💡 Hint</summary>
# Define e such that the derivative has coefficient 1. Turns out e = lim(1+1/n)ⁿ satisfies this!
# </details>
#
# <details>
# <summary>🔍 Deep Dive</summary>
# This property makes e the "natural" base. In calculus, eˣ appears constantly because it's unchanged by differentiation. The Taylor series eˣ = 1 + x + x²/2! + x³/3! + ... shows e connects polynomials and exponentials. In differential equations, eˣ solves y' = y, the simplest growth equation.
# </details>
#
# ### Question 2: How do neural networks use function composition?
# **Context:** Deep learning = composition of layers.
#
# <details>
# <summary>💡 Hint</summary>
# h(x) = f_L(...f_2(f_1(x))...) where each f_i(x) = σ(W_i x + b_i). Composition of affine + nonlinear transformations.
# </details>
#
# ### Question 3: Why do exponentials dominate polynomials?
# **Context:** For large x, 2ˣ > x¹⁰⁰⁰ eventually.
#
# <details>
# <summary>💡 Hint</summary>
# Exponential: multiply by constant each step. Polynomial: add decreasing amounts. Multiplication compounds faster than addition!
# </details>
#
# ### Question 4: What makes a function invertible?
# **Context:** Beyond horizontal line test, deeper understanding.
#
# <details>
# <summary>💡 Hint</summary>
# Bijection = injection (one-to-one) + surjection (onto). Must map each input to unique output and cover entire codomain.
# </details>
#
# ### Question 5: How does continuous compounding lead to e?
# **Context:** A = P(1 + r/n)^(nt) → Pe^(rt) as n → ∞.
#
# <details>
# <summary>💡 Hint</summary>
# Let m = n/r. Then (1 + r/n)^(nt) = [(1 + 1/m)^m]^(rt). As n→∞, m→∞, and (1+1/m)^m → e by definition!
# </details>
#
# ---
#
# ## 📝 Quick Review Quiz
#
# Test your understanding! (Answers at bottom)
#
# ### 1. Multiple Choice
# **Which statement is TRUE about f(x) = eˣ?**
# - A) Domain is (0, ∞)
# - B) Range is ℝ
# - C) Graph passes through (0, 1)
# - D) Function is decreasing
#
# ### 2. Calculation
# **Simplify: (2³ · 2⁵) / 2⁴**
#
# ### 3. Inverse
# **Find f⁻¹(x) if f(x) = 3x - 7**
#
# ### 4. Composition
# **If f(x) = x + 1 and g(x) = x², find (g∘f)(2)**
#
# ### 5. Application
# **$1000 invested at 6% annual rate, compounded continuously. How much after 5 years?**
#
# ---
#
# ### Quiz Answers
#
# 1. **C) Graph passes through (0, 1)**
#    - e⁰ = 1, so (0,1) is on graph
#    - Domain is ℝ, not (0,∞)
#    - Range is (0,∞), not ℝ
#    - Function is increasing, not decreasing
#
# 2. **(2³ · 2⁵) / 2⁴ = 2⁽³⁺⁵⁻⁴⁾ = 2⁴ = 16**
#    - Product rule: aᵐ · aⁿ = aᵐ⁺ⁿ
#    - Quotient rule: aᵐ / aⁿ = aᵐ⁻ⁿ
#
# 3. **f⁻¹(x) = (x + 7)/3**
#    - y = 3x - 7
#    - y + 7 = 3x
#    - x = (y + 7)/3
#    - Swap: f⁻¹(x) = (x + 7)/3
#    - Verify: f(f⁻¹(x)) = 3·(x+7)/3 - 7 = x ✓
#
# 4. **(g∘f)(2) = g(f(2)) = g(3) = 9**
#    - f(2) = 2 + 1 = 3
#    - g(3) = 3² = 9
#    - Or: (g∘f)(x) = g(x+1) = (x+1)², so (g∘f)(2) = 3² = 9
#
# 5. **A = 1000 · e^(0.06·5) = 1000 · e^0.3 ≈ $1349.86**
#    - Continuous compounding: A = Pe^(rt)
#    - P = 1000, r = 0.06, t = 5
#    - e^0.3 ≈ 1.34986
#
# ---
#
# ## 🎯 Action Items for Mastery
#
# ### Before Moving to Week 6:
# 1. **Review all cells** in this notebook - run and understand
# 2. **Complete practice notebook** - hands-on implementations
# 3. **Solve 5 problems each** on exponentials, inverses, composition
# 4. **Graph by hand:** 2ˣ, eˣ, and their inverses (preview ln)
# 5. **Watch 3Blue1Brown** on e and Euler's formula
# 6. **Real-world application:** Find exponential growth in news
#
# ### Challenge Yourself:
# 1. **Prove e's limit definition** converges to 2.718...
# 2. **Implement sigmoid** and plot (ML activation function)
# 3. **Compound interest calculator** - compare discrete vs continuous
# 4. **Derive e from calculus** - solve y' = y
# 5. **Explore Taylor series** - eˣ = Σ xⁿ/n!
#
# ---
#
# **🎉 Congratulations on completing Week 5!**
#
# You now understand:
# - **Exponential functions** - the foundation of growth/decay models
# - **Inverse functions** - reversing transformations
# - **Function composition** - building complex from simple
# - **Real applications** - compound interest, population, ML
#
# **Key Takeaway:** Exponentials break the polynomial pattern! They grow faster than any polynomial, appear everywhere in nature and ML, and connect deeply to calculus through e.
#
# **Coming next:** Logarithms unlock exponential equations! 🔓
#
# ---
#
# **Last Updated:** November 16, 2025
# **Course:** BSMA1001 - Mathematics for Data Science I
# **Institution:** IIT Madras BS Degree Programme
# **Next Topic:** Week 6 - Logarithmic Functions
