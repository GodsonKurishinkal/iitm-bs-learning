# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from typing import TYPE_CHECKING

if TYPE_CHECKING:
    from pandas import DataFrame, Series

np.random.seed(42)
# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 1. Two-Sample t-Tests
# ### 1.1 Theory
# Compare means of two independent groups. Tests whether the difference is statistically significant.
#
# ### 1.2 Mathematical Definition
# $$t = \frac{\bar{X}_1 - \bar{X}_2}{s_p\sqrt{1/n_1 + 1/n_2}}$$
#
# where $s_p$ is pooled standard deviation (assuming equal variances)

# %%
# 1. Two-Sample t-Test - Implementation
# TODO: Add independent samples t-test
pass

# %% [markdown]
# ### 1.3 Supply Chain Application
# **Retail Context**: Compare lead times between suppliers, compare sales between regions, compare fulfillment times between warehouses.

# %%
# Supply Chain Example: Supplier Comparison
# TODO: Add supplier lead time comparison
pass

# %% [markdown]
# ## 2. Paired t-Tests
# ### 2.1 Theory
# When observations are paired (before/after, matched subjects), use paired t-test on differences.
#
# ### 2.2 Mathematical Definition
# $$t = \frac{\bar{d}}{s_d/\sqrt{n}}$$ where $d_i = X_{1i} - X_{2i}$

# %%
# 2. Paired t-Test - Implementation
# TODO: Add paired samples t-test
pass

# %% [markdown]
# ### 2.3 Supply Chain Application
# **Retail Context**: Before/after process improvement, same store different periods, A/B test on same customers.

# %% [markdown]
# ## 3. ANOVA
# ### 3.1 Theory
# Analysis of Variance compares means across more than two groups simultaneously.
#
# ### 3.2 Mathematical Definition
# $$F = \frac{\text{Between-group variance}}{\text{Within-group variance}}$$

# %%
# 3. ANOVA - Implementation
# TODO: Add one-way ANOVA
pass

# %% [markdown]
# ### 3.3 Supply Chain Application
# **Retail Context**: Compare performance across multiple warehouses, product categories, or time periods.

# %% [markdown]
# ## Practice Exercises
# 1. **Exercise 1**: Compare average order values between two customer segments.
# 2. **Exercise 2**: Test if a promotion increased sales (before vs after, same stores).
# 3. **Exercise 3**: Compare lead times across three suppliers using ANOVA.

# %% [markdown]
# ## Summary
# - Two-sample t-test: independent group comparison
# - Paired t-test: matched/repeated measures
# - ANOVA: 3+ group comparison
# - Chi-square: categorical variable association
#
# ## Next Week Preview
# Week 10 covers **Simple Regression** - modeling relationships between variables.
#
# ---
# *IIT Madras BS Degree in Data Science*
