# %% [markdown]
# # Week 2: Independence and Conditional Probability
#
# **Course:** Statistics for Data Science II (BSST1002)
# **Week:** 2
#
# ## Learning Objectives
# - Understand independence and conditional probability concepts
# - Apply statistical methods to real data
# - Implement using NumPy, SciPy, and Pandas
# - Interpret results for data science

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## Section 1: Independence and Conditional Probability Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Independence and Conditional Probability implementation
print('Week 2: Independence and Conditional Probability - Cell 4')

# %% [markdown]
# ## Section 2: Independence and Conditional Probability Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Independence and Conditional Probability implementation
print('Week 2: Independence and Conditional Probability - Cell 6')

# %% [markdown]
# ## Section 3: Independence and Conditional Probability Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Independence and Conditional Probability implementation
print('Week 2: Independence and Conditional Probability - Cell 8')

# %% [markdown]
# ## Section 4: Independence and Conditional Probability Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Independence and Conditional Probability implementation
print('Week 2: Independence and Conditional Probability - Cell 10')

# %% [markdown]
# ## Section 5: Independence and Conditional Probability Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Independence and Conditional Probability implementation
print('Week 2: Independence and Conditional Probability - Cell 12')

# %% [markdown]
# ## Section 6: Independence and Conditional Probability Concepts
#
# Statistical theory with formulas and interpretations.
