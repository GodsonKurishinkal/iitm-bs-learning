# %% [markdown]
# # Week 6: Point Estimation
#
# **Course:** Statistics for Data Science II (BSST1002)
# **Week:** 6
#
# ## Learning Objectives
# - Understand point estimation concepts
# - Apply statistical methods to real data
# - Implement using NumPy, SciPy, and Pandas
# - Interpret results for data science

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## Section 1: Point Estimation Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Point Estimation implementation
print('Week 6: Point Estimation - Cell 4')

# %% [markdown]
# ## Section 2: Point Estimation Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Point Estimation implementation
print('Week 6: Point Estimation - Cell 6')

# %% [markdown]
# ## Section 3: Point Estimation Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Point Estimation implementation
print('Week 6: Point Estimation - Cell 8')

# %% [markdown]
# ## Section 4: Point Estimation Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Point Estimation implementation
print('Week 6: Point Estimation - Cell 10')

# %% [markdown]
# ## Section 5: Point Estimation Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Point Estimation implementation
print('Week 6: Point Estimation - Cell 12')
