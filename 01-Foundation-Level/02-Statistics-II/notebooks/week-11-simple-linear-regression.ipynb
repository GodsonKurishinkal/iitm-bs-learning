# %% [markdown]
# # Week 11: Simple Linear Regression
#
# **Course:** Statistics for Data Science II (BSST1002)
# **Week:** 11
#
# ## Learning Objectives
# - Master simple linear regression techniques
# - Apply to real-world data analysis
# - Interpret statistical results
# - Implement using Python libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## Section 1: Simple Linear Regression - Theory
#
# Statistical methodology with formulas, assumptions, and interpretations.
#
# ### Key Concepts
# - Mathematical foundations
# - Practical applications
# - Decision rules and criteria

# %%
# Simple Linear Regression - Implementation Example 2
print('Week 11: Simple Linear Regression')
print('Cell 4: Practical implementation')

# Generate sample data
np.random.seed(42 + 4)
n = 100
data = np.random.randn(n)

print(f'Sample size: {len(data)}')
print(f'Mean: {data.mean():.4f}')
print(f'Std Dev: {data.std(ddof=1):.4f}')

# %% [markdown]
# ## Section 2: Simple Linear Regression - Theory
#
# Statistical methodology with formulas, assumptions, and interpretations.
#
# ### Key Concepts
# - Mathematical foundations
# - Practical applications
# - Decision rules and criteria

# %%
# Simple Linear Regression - Implementation Example 3
print('Week 11: Simple Linear Regression')
print('Cell 6: Practical implementation')

# Generate sample data
np.random.seed(42 + 6)
n = 100
data = np.random.randn(n)

print(f'Sample size: {len(data)}')
print(f'Mean: {data.mean():.4f}')
print(f'Std Dev: {data.std(ddof=1):.4f}')

# %% [markdown]
# ## Section 3: Simple Linear Regression - Theory
#
# Statistical methodology with formulas, assumptions, and interpretations.
#
# ### Key Concepts
# - Mathematical foundations
# - Practical applications
# - Decision rules and criteria

# %%
# Simple Linear Regression - Implementation Example 4
print('Week 11: Simple Linear Regression')
print('Cell 8: Practical implementation')

# Generate sample data
np.random.seed(42 + 8)
n = 100
data = np.random.randn(n)

print(f'Sample size: {len(data)}')
print(f'Mean: {data.mean():.4f}')
print(f'Std Dev: {data.std(ddof=1):.4f}')

# %% [markdown]
# ## Section 4: Simple Linear Regression - Theory
#
# Statistical methodology with formulas, assumptions, and interpretations.
#
# ### Key Concepts
# - Mathematical foundations
# - Practical applications
# - Decision rules and criteria

# %%
# Simple Linear Regression - Implementation Example 5
print('Week 11: Simple Linear Regression')
print('Cell 10: Practical implementation')

# Generate sample data
np.random.seed(42 + 10)
n = 100
data = np.random.randn(n)

print(f'Sample size: {len(data)}')
print(f'Mean: {data.mean():.4f}')
print(f'Std Dev: {data.std(ddof=1):.4f}')

# %% [markdown]
# ## Section 5: Simple Linear Regression - Theory
#
# Statistical methodology with formulas, assumptions, and interpretations.
#
# ### Key Concepts
# - Mathematical foundations
# - Practical applications
# - Decision rules and criteria

# %%
# Simple Linear Regression - Implementation Example 6
print('Week 11: Simple Linear Regression')
print('Cell 12: Practical implementation')

# Generate sample data
np.random.seed(42 + 12)
n = 100
data = np.random.randn(n)

print(f'Sample size: {len(data)}')
print(f'Mean: {data.mean():.4f}')
print(f'Std Dev: {data.std(ddof=1):.4f}')

# %% [markdown]
# ## Section 6: Simple Linear Regression - Theory
#
# Statistical methodology with formulas, assumptions, and interpretations.
#
# ### Key Concepts
# - Mathematical foundations
# - Practical applications
# - Decision rules and criteria

# %%
# Simple Linear Regression - Implementation Example 7
print('Week 11: Simple Linear Regression')
print('Cell 14: Practical implementation')

# Generate sample data
np.random.seed(42 + 14)
n = 100
data = np.random.randn(n)

print(f'Sample size: {len(data)}')
print(f'Mean: {data.mean():.4f}')
print(f'Std Dev: {data.std(ddof=1):.4f}')

# %% [markdown]
# ## Section 7: Simple Linear Regression - Theory
#
# Statistical methodology with formulas, assumptions, and interpretations.
#
# ### Key Concepts
# - Mathematical foundations
# - Practical applications
# - Decision rules and criteria

# %% [markdown]
# ## Summary: Simple Linear Regression
#
# ### Key Takeaways
# 1. Fundamental concepts and formulas
# 2. Practical implementation in Python
# 3. Interpretation of results
# 4. Real-world applications
#
# ### Statistical Methods Covered
# - Theoretical foundations
# - Computational techniques
# - Decision-making frameworks
#
# ### Next Steps
# - Apply to your own datasets
# - Explore advanced variations
# - Practice interpretation skills
#
# **Next Week:** Week 12
