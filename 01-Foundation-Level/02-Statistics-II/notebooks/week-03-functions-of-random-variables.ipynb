# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from typing import TYPE_CHECKING

if TYPE_CHECKING:
    from pandas import DataFrame, Series

np.random.seed(42)
# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 1. Transformations of Random Variables
# ### 1.1 Theory
# When we apply functions to random variables, we get new random variables with different distributions.
#
# ### 1.2 Mathematical Definition
# If $Y = g(X)$ and $g$ is monotonic:
# $$f_Y(y) = f_X(g^{-1}(y)) \cdot |\frac{d}{dy}g^{-1}(y)|$$
#
# **Common transformations**: Linear ($aX + b$), log, exponential, square

# %%
# 1. Transformations - Implementation
# TODO: Add transformation examples
pass

# %% [markdown]
# ### 1.3 Supply Chain Application
# **Retail Context**: Revenue = Price × Quantity; log-transformed demand for multiplicative models; squared error for loss functions.

# %%
# Supply Chain Example: Revenue Distribution
# TODO: Add price × quantity distribution
pass

# %% [markdown]
# ## 2. Expected Value of Functions
# ### 2.1 Theory
# We can find expected values without deriving the full distribution of the transformation.
#
# ### 2.2 Mathematical Definition
# **Law of the Unconscious Statistician (LOTUS)**:
# $$E[g(X)] = \sum_x g(x) p(x) \quad \text{or} \quad E[g(X)] = \int g(x) f(x) dx$$

# %%
# 2. LOTUS - Implementation
# TODO: Add LOTUS examples
pass

# %% [markdown]
# ### 2.3 Supply Chain Application
# **Retail Context**: Expected profit = E[Revenue - Cost]. Expected holding cost under uncertain demand. Expected service level.

# %%
# Supply Chain Example: Expected Profit
# TODO: Add expected profit calculation
pass

# %% [markdown]
# ## Practice Exercises
# 1. **Exercise 1**: If demand D ~ Poisson(λ), find the distribution of log(D+1).
# 2. **Exercise 2**: Calculate expected revenue when price and quantity are random.
# 3. **Exercise 3**: Find expected squared error of a forecast.

# %% [markdown]
# ## Summary
# - Functions of RVs create new RVs with transformed distributions
# - Jacobian formula handles monotonic transformations
# - LOTUS: find E[g(X)] directly without deriving distribution of g(X)
# - These tools enable profit and loss analysis
#
# ## Next Week Preview
# Week 4 covers **Continuous Joint Distributions** - bivariate Normal and more.
#
# ---
# *IIT Madras BS Degree in Data Science*
