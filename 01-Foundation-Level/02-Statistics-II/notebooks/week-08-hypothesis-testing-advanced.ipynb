# %% [markdown]
# # Week 8: Hypothesis Testing Advanced
#
# **Course:** Statistics for Data Science II (BSMA1004)
# **Week:** 8 of 12
#
# ## Learning Objectives
# - Two-sample tests
# - Paired t-tests
# - Non-parametric tests
# - Multiple testing corrections

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## Comprehensive Content
#
# This notebook covers all key concepts for Week 8: Hypothesis Testing Advanced
#
# Topics include:
# - Two-sample tests
# - Paired t-tests
# - Non-parametric tests
# - Multiple testing corrections

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Two-sample tests
# 1. Paired t-tests
# 1. Non-parametric tests
#
# ### 🚀 Next Week
# **Week 9**
#
# ---
# **🎓 End of Week 8**
