# %% [markdown]
# # Week 9: Chi-Square Tests
#
# **Course:** Statistics for Data Science II (BSMA1004)
# **Week:** 9 of 12
#
# ## Learning Objectives
# - Goodness of fit tests
# - Tests of independence
# - Contingency tables
# - McNemar's test

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## Comprehensive Content
#
# This notebook covers all key concepts for Week 9: Chi-Square Tests
#
# Topics include:
# - Goodness of fit tests
# - Tests of independence
# - Contingency tables
# - McNemar's test

# %% [markdown]
# ## Summary & Key Takeaways
#
# ### 📚 Core Concepts
# 1. Goodness of fit tests
# 1. Tests of independence
# 1. Contingency tables
#
# ### 🚀 Next Week
# **Week 10**
#
# ---
# **🎓 End of Week 9**
