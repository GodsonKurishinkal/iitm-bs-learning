# %% [markdown]
# # Week 3: Expectations and Covariance
#
# **Course:** Statistics for Data Science II (BSST1002)
# **Week:** 3
#
# ## Learning Objectives
# - Understand expectations and covariance concepts
# - Apply statistical methods to real data
# - Implement using NumPy, SciPy, and Pandas
# - Interpret results for data science

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

np.random.seed(42)
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

print('✓ Libraries loaded')

# %% [markdown]
# ## Section 1: Expectations and Covariance Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Expectations and Covariance implementation
print('Week 3: Expectations and Covariance - Cell 4')

# %% [markdown]
# ## Section 2: Expectations and Covariance Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Expectations and Covariance implementation
print('Week 3: Expectations and Covariance - Cell 6')

# %% [markdown]
# ## Section 3: Expectations and Covariance Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Expectations and Covariance implementation
print('Week 3: Expectations and Covariance - Cell 8')

# %% [markdown]
# ## Section 4: Expectations and Covariance Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Expectations and Covariance implementation
print('Week 3: Expectations and Covariance - Cell 10')

# %% [markdown]
# ## Section 5: Expectations and Covariance Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Expectations and Covariance implementation
print('Week 3: Expectations and Covariance - Cell 12')

# %% [markdown]
# ## Section 6: Expectations and Covariance Concepts
#
# Statistical theory with formulas and interpretations.

# %%
# Expectations and Covariance implementation
print('Week 3: Expectations and Covariance - Cell 14')
